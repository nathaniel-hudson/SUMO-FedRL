# %%
import ast
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from os.path import join

# %%
filename = join("..", "out", "data", "MARL", "grid-5x5", "v3_unranked.csv")
df = pd.read_csv(filename)
df.head()
# Out:
#    Unnamed: 0  round trainer  fed_round  ranked  weight_aggr_fn  \
# 0           0      0    MARL      False   False             NaN
# 1           1      1    MARL      False   False             NaN
# 2           2      2    MARL      False   False             NaN
# 3           3      3    MARL      False   False             NaN
# 4           4      4    MARL      False   False             NaN
#
#    episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0         -140.356792         -165.118474          -152.544795
# 1         -131.510783         -165.118474          -150.758859
# 2         -121.087974         -173.476636          -147.503541
# 3         -121.087974         -173.476636          -145.503656
# 4         -121.087974         -173.476636          -144.067453
#
#    episode_len_mean  ... time_total_s    pid hostname       node_ip  \
# 0             360.0  ...  1155.081733  15580     mako  172.31.40.24
# ...

# %%
d = ast.literal_eval(df["hist_stats"][10])
d.keys()
# Out:
# dict_keys(['policy_A2_comm=edge-to-tls-policy-comms', 'policy_A2_comm=tls-to-edge-policy-comms', 'policy_A2_comm=edge-to-tls-action-comms', 'policy_A2_comm=edge-to-tls-rank-comms', 'policy_A2_comm=tls-to-edge-obs-comms', 'policy_A2_comm=veh-to-tls-info-comms', 'policy_B2_comm=edge-to-tls-policy-comms', 'policy_B2_comm=tls-to-edge-policy-comms', 'policy_B2_comm=edge-to-tls-action-comms', 'policy_B2_comm=edge-to-tls-rank-comms', 'policy_B2_comm=tls-to-edge-obs-comms', 'policy_B2_comm=veh-to-tls-info-comms', 'policy_B3_comm=edge-to-tls-policy-comms', 'policy_B3_comm=tls-to-edge-policy-comms', 'policy_B3_comm=edge-to-tls-action-comms', 'policy_B3_comm=edge-to-tls-rank-comms', 'policy_B3_comm=tls-to-edge-obs-comms', 'policy_B3_comm=veh-to-tls-info-comms', 'policy_E4_comm=edge-to-tls-policy-comms', 'policy_E4_comm=tls-to-edge-policy-comms', 'policy_E4_comm=edge-to-tls-action-comms', 'policy_E4_comm=edge-to-tls-rank-comms', 'policy_E4_comm=tls-to-edge-obs-comms', 'policy_E4_comm=veh-to-tls-
# ...
